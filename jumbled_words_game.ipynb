# %% [markdown]
# <a href="https://colab.research.google.com/github/Shambhavi-Gupta/jumbled_words_game-python/blob/master/jumbled_words_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random 
  
  

def choose(): 
    
    words = ['rainbow', 'computer', 'science', 'programming', 
             'mathematics', 'player', 'condition', 'reverse', 
             'water', 'board', 'temperature'] 
  
   
    pick = random.choice(words) 
  
    return pick 
  
  

def jumble(word): 
    
    random_word = random.sample(word, len(word)) 
    jumbled = ''.join(random_word) 
    return jumbled 
  
def thank(p1n, p2n, p1, p2): 
    print(p1n, 'Your score is :', p1) 
    print(p2n, 'Your score is :', p2) 
  
     
    check_win(p1n, p2n, p1, p2) 
  
    print('Thanks for playing...') 
  
  

def check_win(player1, player2, p1score, p2score): 
    if p1score > p2score: 
        print("winner is :", player1) 
    elif p2score > p1score: 
        print("winner is :", player2) 
    else: 
        print("Draw..Well Played guys..") 
  
  

def play(): 
    
    p1name = input("player 1, Please enter your name :") 
    p2name = input("Player 2 , Please enter your name: ") 
    print("So...let's begin the game")
    
    pp1 = 0
    pp2 = 0
    turn = 0
   
    while True: 
  
       
        picked_word = choose() 
  
       
        qn = jumble(picked_word) 
        print("jumbled word is :", qn) 
  
       
        if turn % 2 == 0: 
  
            
            print(p1name, 'Your Turn.') 
  
            ans = input("what is in your mind? ") 
  
            if ans == picked_word: 
                pp1 += 1
  
                print('Your score is :', pp1) 
                turn += 1
  
            else: 
                print("Better luck next time ..") 
  
               
                print(p2name, 'Your turn.') 
  
                ans = input('what is in your mind? ') 
  
                if ans == picked_word: 
                    pp2 += 1
                    print("Your Score is :", pp2) 
  
                else: 
                    print("Better luck next time...correct word is :", picked_word) 
  
                c = int(input("press 1 to continue and 0 to quit :")) 
  
                
                if c == 0: 
                    
                    thank(p1name, p2name, pp1, pp2) 
                    break
  
        else: 
  
           
            print(p2name, 'Your turn.') 
            ans = input('what is in your mind? ') 
  
            if ans == picked_word: 
                pp2 += 1
                print("Your Score is :", pp2) 
                turn += 1
  
            else: 
                print("Better luck next time.. :") 
                print(p1name, 'Your turn.') 
                ans = input('what is in your mind? ') 
  
                if ans == picked_word: 
                    pp1 += 1
                    print("Your Score is :", pp1) 
  
                else: 
                    print("Better luck next time...correct word is :", picked_word) 
  
                    c = int(input("press 1 to continue and 0 to quit :")) 
  
                    if c == 0: 
                        
                        thank(p1name, p2name, pp1, pp2) 
                        break
  
            c = int(input("press 1 to continue and 0 to quit :")) 
            if c == 0: 
                
                thank(p1name, p2name, pp1, pp2) 
                break
  
  
# Driver code 
if __name__ == '__main__': 
      play()
# Out:
# player 1, Please enter your name :om
# Player 2 , Please enter your name: mo
# So...let's begin the game
# jumbled word is : roabd
# om Your Turn.
# what is in your mind? board
# Your score is : 1
# jumbled word is : bador
# mo Your turn.
# what is in your mind? board
# Your Score is : 1
# press 1 to continue and 0 to quit :1
# jumbled word is : aelrpy
# om Your Turn.
# what is in your mind? replay
# Better luck next time ..
# mo Your turn.
# what is in your mind? player
# Your Score is : 2
# press 1 to continue and 0 to quit :1
# jumbled word is : etmrpouc
# om Your Turn.
# what is in your mind? computer
# Your score is : 2
# jumbled word is : ueartrepemt
# mo Your turn.
# what is in your mind? temperature
# Your Score is : 3
# press 1 to continue and 0 to quit :0
# om Your score is : 2
# mo Your score is : 3
# winner is : mo
# Thanks for playing...
